# %% [markdown]
# # MEGA

# %% [markdown]
# ### Задание 1
# Найдём от 3 последовательности S-белка SARS-CoV-2

# %% [markdown]
# Ухань
# >[OP168693.1 Severe acute respiratory syndrome coronavirus 2 isolate SARS-CoV-2/human/MLI/Wuhan-Hu-1-153/2021 surface glycoprotein (S) gene, complete cds](https://www.ncbi.nlm.nih.gov/nuccore/OP168693.1)
#
# Казахстан
# >[MW672572.1 Severe acute respiratory syndrome coronavirus 2 isolate SARS-CoV-2/human/KAZ/KZ_Almaty/2020 surface glycoprotein (S) gene, partial cds](https://www.ncbi.nlm.nih.gov/nuccore/MW672572.1/)
#
# Бразилия:
# >[OM064633.1 Severe acute respiratory syndrome coronavirus 2 isolate SARS-CoV-2/human/BRA/RJ-LIVIC-B1/2021 surface glycoprotein (S) gene, complete cds](https://www.ncbi.nlm.nih.gov/nuccore/OM064633.1)
#
# США:
# >[MZ056531.1 Severe acute respiratory syndrome coronavirus 2 isolate SARS-CoV-2/human/USA/9210027241/2021 surface glycoprotein (S) gene, complete cds](https://www.ncbi.nlm.nih.gov/nuccore/MZ056531.1)

# %% [markdown]
# Провели выравнивание ClustalW и сохранили в файл mega
# ![image.png](attachment:57f2954d-f284-4fbb-b42e-cf5022cab83f.png)

# %% [markdown]
# Теперь построим филогенетическое дерево (пробовала разные способы, примерно одинаково):
# ![image.png](attachment:4a0c8594-3f1a-4303-ad9e-fd9178c9dd44.png)

# %% [markdown]
# Сложно сделать вывод об эволюции  короновируса на четырёх последовательностях. Однако логично, что наиболее базальной является последовательность из Уханя, которая появилась первой. А вот остальное я бы не стала интерпретировать

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Найдём в базе данных ортологов последовательности гена ластазы LCT и посмотрим на дерево точно так же как и впервом пункте:
# ![image.png](attachment:767b9e63-1783-42c7-a584-53ce29622fde.png)

# %% [markdown]
# ![image.png](attachment:55719985-2b45-416e-bbca-a7491fab2d2f.png)

# %% [markdown]
# У нас построилось прекрасное логичное дерево: образовалась ветвь грызунов, человек и макака и правда родственнее всего, а птицы и черепахи дальше всех от остальных выбранных животных.
#
# Также можно построить красивые аналогичные деревья:

# %% [markdown]
# ![image.png](attachment:15717a10-0bc2-4f5e-905a-2a6297cf0d7e.png)
# ![image.png](attachment:ee66b36e-01d5-4270-bd25-da0288798990.png)
