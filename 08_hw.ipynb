# %% [markdown]
# ## В этом ноутбуке оставлю выводы работы bash-скриптов в ДЗ 8

# %% [markdown]
# # Задание 1

# %% [markdown]
# ![image.png](attachment:972d60c2-940f-4d4c-a393-5d724d7be250.png)

# %% [markdown]
# Остальные задания выполнялись аналогичным способом, поэтому оставлю только вывод результатов

# %% [markdown]
# # Задание 2

# %% [markdown]
# ![image.png](attachment:670406ed-2612-4838-b409-277c048706f7.png)

# %% [markdown]
# # Задание 3

# %% [markdown]
# ![image.png](attachment:a1ccd1c9-568a-460e-aa07-b4e498447b69.png)

# %% [markdown]
# # Задание 4

# %% [markdown]
# ![image.png](attachment:603be567-1bd5-47cf-8da8-7e1d10f49572.png)

# %% [markdown]
# # Задание 5

# %% [markdown]
# ![image.png](attachment:a3a6443d-8469-4a8d-84bd-72a19ed672d8.png)

# %% [markdown]
# # Задание 6

# %% [markdown]
# В папке для 6 задания было 2 тестовых файла fin (6.1 и 6.2) - для обоих вывела результат:

# %% [markdown]
# ![image.png](attachment:f4073461-d324-4c7f-9d20-c588c0f85141.png)

# %% [markdown]
# # Задание 7

# %% [markdown]
# ![image.png](attachment:4e7dfa1c-4dde-46b7-8bdf-2d09e5f817ef.png)
